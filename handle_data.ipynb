# %%
import pandas as pd
import os
import re
import json

def as_html(df):
    with open("view.html", "w", encoding="utf-8") as f:
        f.write(df.to_html())

# %%
df = pd.DataFrame()

for csv in os.listdir("data"):
    new_data = pd.read_csv(f"data\\{csv}")
    clubname = csv.replace(".csv", "")

    new_data["clubname"] = clubname

    df = pd.concat((df, new_data))

# %%
pos_mapper = {pos:[1,1,1] for pos in df["Pos"].unique()}
pos_mapper
# Out:
# {'Goalkeeper': [1, 1, 1],
#  'Centre-Back': [1, 1, 1],
#  'Left-Back': [1, 1, 1],
#  'Right-Back': [1, 1, 1],
#  'Defensive Midfield': [1, 1, 1],
#  'Central Midfield': [1, 1, 1],
#  'Attacking Midfield': [1, 1, 1],
#  'Left Winger': [1, 1, 1],
#  'Right Winger': [1, 1, 1],
#  'Second Striker': [1, 1, 1],
#  'Centre-Forward': [1, 1, 1],
#  'Striker': [1, 1, 1]}

# %%
def get_year(strg):
    pattern = r"(\d{4})"

    m = re.search(pattern, strg)
    if m:
        year= m.group()
        return int(year)
    return False

df["Birthday"] = [get_year(i) for i in df["Birthday"]]

df.tail()
# Out:
#    Num              Name             Pos  Birthday   value  \
# 31  10           Luciano  Second Striker      1993  €2.00m
# 32  49    Ryan Francisco  Centre-Forward      2006  €6.00m
# 33  17       André Silva  Centre-Forward      1997  €5.00m
# 34   9  Jonathan Calleri  Centre-Forward      1993  €2.50m
# 35  19      Juan Dinenno  Centre-Forward      1994  €2.50m
#
#                    clubname
# 31  São Paulo Futebol Clube
# 32  São Paulo Futebol Clube
# 33  São Paulo Futebol Clube
# 34  São Paulo Futebol Clube
# 35  São Paulo Futebol Clube

# %%
def get_value(strg):
    from random import randint
    pattern = r"€([\d.,]+)([mk])"

    m = re.search(pattern, strg, re.IGNORECASE)
    if m:
        value, suffix = m.groups()

        value.replace(",", ".")
        
        if "m" in suffix:
            value = float(value) * 1e3
        elif "k" in suffix:
            value = float(value) 
        print(value)
        return value
    return randint(1, 100)


df["value_1k"] = [get_value(i) for i in df["value"]]
df = df[[i for i in df.columns if i != "value"]]
# Out:
# 8000.0
# 1500.0
# 350.0
# 100.0
# 5000.0
# 2500.0
# 1800.0
# 900.0
# 350.0
# 8000.0
# 4000.0
# 300.0
# 6000.0
# 2000.0
# 350.0
# 28000.0
# 6000.0
# 4000.0
# 2500.0
# 2000.0
# 1000.0
# 2000.0
# 10000.0
# 4500.0
# 3500.0
# 1000.0
# 400.0
# 7000.0
# 5000.0
# 1000.0
# 8000.0
# 6000.0
# 2200.0
# 1500.0
# 3000.0
# 10000.0
# 5000.0
# 2000.0
# 1500.0
# 1000.0
# 1000.0
# 300.0
# 200.0
# 100.0
# 900.0
# 550.0
# 500.0
# 450.0
# 450.0
# 100.0
# 3000.0
# 1000.0
# 1700.0
# 1500.0
# 500.0
# 200.0
# 150.0
# 2000.0
# 1800.0
# 2000.0
# 2000.0
# 300.0
# 3000.0
# 2500.0
# 2000.0
# 1500.0
# 800.0
# 2000.0
# 2000.0
# 1200.0
# 700.0
# 6000.0
# 1000.0
# 4000.0
# 3000.0
# 2000.0
# 12000.0
# 2000.0
# 1000.0
# 1000.0
# 14000.0
# 7000.0
# 1000.0
# 250.0
# 22000.0
# 10000.0
# 1000.0
# 1000.0
# 700.0
# 100.0
# 1500.0
# 1500.0
# 1000.0
# 700.0
# 550.0
# 400.0
# 250.0
# 800.0
# 750.0
# 400.0
# 1500.0
# 800.0
# 3000.0
# 3000.0
# 1800.0
# 1700.0
# 1500.0
# 1500.0
# 1000.0
# 500.0
# 3000.0
# 1700.0
# 1000.0
# 750.0
# 2000.0
# 1000.0
# 700.0
# 600.0
# 4000.0
# 3500.0
# 1300.0
# 12000.0
# 5000.0
# 3000.0
# 1000.0
# 800.0
# 200.0
# 7000.0
# 2000.0
# 6000.0
# 2500.0
# 450.0
# 5000.0
# 1000.0
# 1000.0
# 1000.0
# 800.0
# 700.0
# 400.0
# 3000.0
# 1200.0
# 200.0
# 9000.0
# 7500.0
# 4000.0
# 12000.0
# 2000.0
# 2000.0
# 7000.0
# 4000.0
# 1700.0
# 1000.0
# 150.0
# 500.0
# 250.0
# 100.0
# 4500.0
# 3000.0
# 1000.0
# 800.0
# 800.0
# 3500.0
# 3000.0
# 1500.0
# 1000.0
# 9000.0
# 1800.0
# 500.0
# 250.0
# 5000.0
# 3000.0
# 2500.0
# 1800.0
# 600.0
# 3500.0
# 8000.0
# 2000.0
# 5000.0
# 4000.0
# 1700.0
# 300.0
# 2000.0
# 6000.0
# 5000.0
# 2500.0
# 2500.0

# %%
mapper = {}

i = 0
cs = []
for k in os.listdir("images"):
    print(f"{i} - {k}")
    cs.append(k)
    i += 1

if False:
    for clubname in os.listdir("data"):
        clubname = clubname.split(".")[0]
        print(clubname)
        a = int(input())
        mapper[clubname] = cs[a]
# Out:
# 0 - Atlético-MG.svg
# 1 - Bahia.svg
# 2 - botafogo de futebol e regatas.svg
# 3 - Bragantino.svg
# 4 - ceará sporting club.svg
# 5 - Corinthians.svg
# 6 - Cruzeiro.svg
# 7 - Flamengo.svg
# 8 - Fluminense.svg
# 9 - Fortaleza.svg
# 10 - Grêmio.svg
# 11 - Internacional.svg
# 12 - Juventude.svg
# 13 - Mirassol.svg
# 14 - Palmeiras.svg
# 15 - Santos.svg
# 16 - Sport.svg
# 17 - São Paulo.svg
# 18 - Vasco.svg
# 19 - Vitória.svg

# %%
mapper = {'Botafogo de Futebol e Regatas': 'botafogo de futebol e regatas.svg',
 'Ceará Sporting Club': 'ceará sporting club.svg',
 'Clube Atlético Mineiro': 'Atlético-MG.svg',
 'Clube de Regatas Vasco da Gama': 'Vasco.svg',
 'CR Flamengo': 'Flamengo.svg',
 'Cruzeiro Esporte Clube': 'Cruzeiro.svg',
 'Esporte Clube Bahia': 'Bahia.svg',
 'Esporte Clube Juventude': 'Juventude.svg',
 'Esporte Clube Vitória': 'Vitória.svg',
 'Fluminense Football Club': 'Fluminense.svg',
 'Fortaleza Esporte Clube': 'Fortaleza.svg',
 'Grêmio Foot-Ball Porto Alegrense': 'Grêmio.svg',
 'Mirassol Futebol Clube (SP)': 'Mirassol.svg',
 'Red Bull Bragantino': 'Bragantino.svg',
 'Santos FC': 'Santos.svg',
 'Sociedade Esportiva Palmeiras': 'Palmeiras.svg',
 'Sport Club Corinthians Paulista': 'Corinthians.svg',
 'Sport Club do Recife': 'Sport.svg',
 'Sport Club Internacional': 'Internacional.svg',
 'São Paulo Futebol Clube': 'São Paulo.svg'}

# %%
# Define a formula for the quality of a player
def evaluate_player(age:int, value:int, position:str):
    # define max_value
    MIN_VALUE, MAX_VALUE = 1, 200000# in 1k euro

    def age_multipliter(age):
        # experience should make the stats
        # slightly bigger
        if age <= 17:
            return .7
        elif age <= 23:
            return .7 + ((age - 18)/(23-18)) * .3
        elif age <= 40:
            return 1 + ((age - 23)/(40-23)) * .3
        else:
            return 1.3
    
    norm_value = age_multipliter(age) * value
    
    def value_to_stat(value):
        from numpy import log as ln
        # log function where
        # if
        # value = 1k -> 30
        # value = 200m -> 100
        return int(5.734850351364555 * ln(value) + 30)

    base_stat = value_to_stat(norm_value)

    pos_mapper = {
        'Goalkeeper': [5, 10, 85],
        'Centre-Back': [10, 20, 70],
        'Left-Back': [15, 25, 60],
        'Right-Back':[15, 25, 60],
        'Defensive Midfield': [20, 20, 40],
        'Central Midfield': [30, 40, 30],
        'Attacking Midfield': [45, 35, 20],
        'Left Winger': [60, 30, 10],
        'Right Winger': [60, 30, 10],
        'Second Striker': [65, 30, 5],
        'Centre-Forward': [70, 25, 5],
        'Striker': [75, 20, 5]
    }

    stats = []
    for mult in pos_mapper[position]:
        mult = (mult) / 100

        s = (.4 * base_stat + .6 * mult * base_stat )
        s = round(s)
        stats.append(s)
    
    return base_stat, *stats

from datetime import datetime

cur_year = datetime.now().year
print(df.columns)
df[["base_stat", "atk", "mid", "dfs"]] = df.apply(
    lambda row: pd.Series(
        evaluate_player(
            age = cur_year - row["Birthday"],
            value=row["value_1k"],
            position=row["Pos"]
        )
    ),
    axis=1
)
df.head(len(df))
# Out:
# Index(['Num', 'Name', 'Pos', 'Birthday', 'clubname', 'value_1k'], dtype='object')
#    Num               Name             Pos  Birthday  \
# 0   12        John Victor      Goalkeeper      1996
# 1   24          Léo Linck      Goalkeeper      2001
# 2   40     Cristhian Loor      Goalkeeper      2006
# 3    1               Raul      Goalkeeper      1997
# 4   20  Alexander Barboza     Centre-Back      1995
# ..  ..                ...             ...       ...
# 31  10            Luciano  Second Striker      1993
# 32  49     Ryan Francisco  Centre-Forward      2006
# 33  17        André Silva  Centre-Forward      1997
# 34   9   Jonathan Calleri  Centre-Forward      1993
# 35  19       Juan Dinenno  Centre-Forward      1994
#
#                          clubname  value_1k  base_stat  atk  mid  dfs
# 0   Botafogo de Futebol e Regatas    8000.0         82   35   38   75
# 1   Botafogo de Futebol e Regatas    1500.0         72   31   33   66
# 2   Botafogo de Futebol e Regatas     350.0         62   27   29   56
# 3   Botafogo de Futebol e Regatas     100.0         56   24   26   51
# 4   Botafogo de Futebol e Regatas    5000.0         79   36   41   65
# ..                            ...       ...        ...  ...  ...  ...
# 31        São Paulo Futebol Clube    2000.0         74   58   43   32
# 32        São Paulo Futebol Clube    6000.0         78   64   43   34
# 33        São Paulo Futebol Clube    5000.0         79   65   43   34
# 34        São Paulo Futebol Clube    2500.0         75   62   41   32
# 35        São Paulo Futebol Clube    2500.0         75   62   41   32
#
# [660 rows x 10 columns]

# %%
as_html(df.sort_values("value_1k", ascending=False))

# %%
basestat_df = df[df["Pos"] != "Goalkeeper"].groupby(["clubname"])[["base_stat", "atk", "mid", "dfs"]].mean()
as_html(basestat_df)

# %%
df["img_path"] = df.apply(lambda row: "images//" + mapper[row["clubname"]], axis=1)
df
# Out:
#    Num               Name             Pos  Birthday  \
# 0   12        John Victor      Goalkeeper      1996
# 1   24          Léo Linck      Goalkeeper      2001
# 2   40     Cristhian Loor      Goalkeeper      2006
# 3    1               Raul      Goalkeeper      1997
# 4   20  Alexander Barboza     Centre-Back      1995
# ..  ..                ...             ...       ...
# 31  10            Luciano  Second Striker      1993
# 32  49     Ryan Francisco  Centre-Forward      2006
# 33  17        André Silva  Centre-Forward      1997
# 34   9   Jonathan Calleri  Centre-Forward      1993
# 35  19       Juan Dinenno  Centre-Forward      1994
#
#                          clubname  value_1k  base_stat  atk  mid  dfs  \
# 0   Botafogo de Futebol e Regatas    8000.0         82   35   38   75
# 1   Botafogo de Futebol e Regatas    1500.0         72   31   33   66
# 2   Botafogo de Futebol e Regatas     350.0         62   27   29   56
# 3   Botafogo de Futebol e Regatas     100.0         56   24   26   51
# 4   Botafogo de Futebol e Regatas    5000.0         79   36   41   65
# ..                            ...       ...        ...  ...  ...  ...
# 31        São Paulo Futebol Clube    2000.0         74   58   43   32
# 32        São Paulo Futebol Clube    6000.0         78   64   43   34
# 33        São Paulo Futebol Clube    5000.0         79   65   43   34
# 34        São Paulo Futebol Clube    2500.0         75   62   41   32
# 35        São Paulo Futebol Clube    2500.0         75   62   41   32
#
#                                      img_path
# 0   images//botafogo de futebol e regatas.svg
# 1   images//botafogo de futebol e regatas.svg
# 2   images//botafogo de futebol e regatas.svg
# 3   images//botafogo de futebol e regatas.svg
# 4   images//botafogo de futebol e regatas.svg
# ..                                        ...
# 31                      images//São Paulo.svg
# 32                      images//São Paulo.svg
# 33                      images//São Paulo.svg
# 34                      images//São Paulo.svg
# 35                      images//São Paulo.svg
#
# [660 rows x 11 columns]

# %%
df = pd.read_csv(r"EU\data\data.csv")
df = df.sort_values("value_1k", ascending=False)
as_html(df)
